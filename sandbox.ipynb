# %%
# %load_ext autoreload

# %autoreload 2

# %%
import pandas as pd

test_df = pd.DataFrame(
  columns = ['a','b'],
  data = [
    [1, -42], # row 0
    [1, None], # row 1
    [1, None], # row 2
    [1, 3.14], # row 3
  ],
  dtype=object # prevent None from being converted to np.nan - ref: https://stackoverflow.com/a/48453225
)

# %%
test_df.where(test_df > 1)
# Out:
#      a     b
# 0  NaN   NaN
# 1  NaN   NaN
# 2  NaN   NaN
# 3  NaN  3.14

# %%
test_df.where(test_df == 1)
# Out:
#    a    b
# 0  1  NaN
# 1  1  NaN
# 2  1  NaN
# 3  1  NaN

# %%
test_df = pd.DataFrame(
  columns = ['a','b'],
  data = [
    [1, -42], # row 0
    [1, None], # row 1
    [1, None], # row 2
    [1, 3.14], # row 3
  ]
)

test_df.where(test_df==1, -test_df)
# Out:
#    a      b
# 0  1  42.00
# 1  1    NaN
# 2  1    NaN
# 3  1  -3.14

# %%
test_df == 1
# Out:
#       a      b
# 0  True  False
# 1  True  False
# 2  True  False
# 3  True  False

# %%
[ x + x for x in test_df['a']]
# Out:
# [2, 2, 2, 2]

# %%
all((test_df == 1)['a'])
# Out:
# True

# %%
import validium as V

sum_eq_zero = V.Validator(
    lambda df: df['a'].sum() == 0, 
    'sum of column "a" must be 0'
)

if not sum_eq_zero.predicate(test_df): # should except on assert
    print('warn:', sum_eq_zero.fail_msg) 

sum_eq = lambda n: V.Validator(
    lambda df: df['a'].sum() == n, 
    'sum of column "a" must be {}'.format(n)
)

sum_eq(4).validate(test_df)
# Out:
# warn: sum of column "a" must be 0

# %%
sum_eq = lambda n: V.Validator(
    lambda df: df['a'].sum() == n, 
    'sum of column "a" must be {}'.format(n)
)

sum_eq(4).validate(test_df)

# %%
test_df[['a','b']]
# Out:
#    a      b
# 0  1 -42.00
# 1  1    NaN
# 2  1    NaN
# 3  1   3.14

# %%
test_df.loc[2:3,'a':'b']
# Out:
#    a     b
# 2  1   NaN
# 3  1  3.14

# %%
nums_df = test_df.loc[[0,3],['a','b']]
print(nums_df.sum())
print('-------')
print(nums_df.sum().sum())
print('-------')
print(nums_df.values.sum())
# Out:
# a     2.00
# b   -38.86
# dtype: float64
# -------
# -36.86
# -------
# -36.86

# %%
nums_df.values
# Out:
# array([[  1.  , -42.  ],
#        [  1.  ,   3.14]])

# %%
v = V.Validator(
    lambda df: df.where(isinstance(df, int)).sum().sum() == 4,
    'its just 4'
)

# %%
test_df.apply(lambda x : isinstance(x,int))
# Out:
# a    False
# b    False
# dtype: bool

# %%
def foo(bar):
    a = list(range(10))
    print(a[bar[0]:bar[1]])

foo([2,7])
# Out:
# [2, 3, 4, 5, 6]

# %%
test_df[test_df == 1].count().sum()
# Out:
# 4

# %%
# lets try to do a simple one:
import validframe as vf

df_pass = pd.DataFrame(
      columns = ['a','b','c'],
      data = [
        [1, -42, 1], # row 0
        [1, None, 1], # row 1
        [1, None, 1], # row 2
        [1, 3.14, 1], # row 3
      ]
    )

# this is how it comes out working with the list of cells rather than the dataframe
# theres brevity in the logic
cv = vf.CellsValidator(
    lambda xs: all([x == 1 for x in xs]), 
    'all must equal 1',
    cols=['a', 'c'], rows=[0, 3]
)

cv.validate(df_pass)

# turns out its way worse when you have to work directly with the dataframe
# its unintuitive and unreadable unless you really really know the DataFrame api
fv = vf.FrameValidator(
    lambda df: df.loc[[0,3],['a','c']][df == 1].count().sum() == df.loc[[0,3],['a','c']].count().sum(),
    'all must equal 1'
)

fv.validate(df_pass)

# abstracting away the slicing helps but still pretty unintuitive and unreadable
fv2 = vf.FrameValidator(
    lambda df: df.where(df == 1).count().sum() == df.count().sum(),
    'all must equal 1',
    cols=['a', 'c'], rows=[0, 3]
)

fv2.validate(df_pass)

# FINAL THOUGHTS: 
# when working with the dataframe directly you end up having to write a predicate function that does more mathy manipulations (eg. reshaping, pivoting, melting, reducing etc) of the dataframe because that's just how the DataFrame api was designed - while for the right developer this might sound like a fun and challenging way to write prediate functions for validators, it really does make for hacky and unfriendly code
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-2bd9df897720> in <module>
#      20 )
#      21
# ---> 22 cv.validate(df_pass)
#      23
#      24 # turns out its way worse when you have to work directly with the dataframe
#
# ~/GitProjects/json2d/validframe/validframe/core.py in validate(self, df)
#      28     # cells = CellsValidator.iter_cells(df)
#      29
# ---> 30     super().validate(cells)
#      31
#      32   @staticmethod
#
# ~/GitProjects/json2d/validframe/.venv/lib/python3.7/site-packages/validium/core.py in validate(self, target)
#      12
#      13   def validate(self, target):
# ---> 14     assert self.predicate(target), self.fail_msg
#
# <ipython-input-29-2bd9df897720> in <lambda>(xs)
#      15 # theres brevity in the logic
#      16 cv = vf.CellsValidator(
# ---> 17     lambda xs: all([x == 1 for x in xs]),
#      18     'all must equal 1',
#      19     cols=['a', 'c'], rows=[0, 3]
#
# <ipython-input-29-2bd9df897720> in <listcomp>(.0)
#      15 # theres brevity in the logic
#      16 cv = vf.CellsValidator(
# ---> 17     lambda xs: all([x == 1 for x in xs]),
#      18     'all must equal 1',
#      19     cols=['a', 'c'], rows=[0, 3]
#
# ~/GitProjects/json2d/validframe/validframe/core.py in iter_cells(df)
#      37     for row_idx in rows_slice:
#      38       for col_name in cols_slice:
# ---> 39         yield df.loc[[row_idx], [col_name]]
#      40
#      41 class RowsValidator(SliceValidator):
#
# ~/GitProjects/json2d/validframe/.venv/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# ~/GitProjects/json2d/validframe/.venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1278         # ugly hack for GH #836
#    1279         if self._multi_take_opportunity(tup):
# -> 1280             return self._multi_take(tup)
#    1281
#    1282         # no shortcut needed
#
# ~/GitProjects/json2d/validframe/.venv/lib/python3.7/site-packages/pandas/core/indexing.py in _multi_take(self, tup)
#    1337         d = {
#    1338             axis: self._get_listlike_indexer(key, axis)
# -> 1339             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#    1340         }
#    1341         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~/GitProjects/json2d/validframe/.venv/lib/python3.7/site-packages/pandas/core/indexing.py in <dictcomp>(.0)
#    1337         d = {
#    1338             axis: self._get_listlike_indexer(key, axis)
# -> 1339             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#    1340         }
#    1341         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~/GitProjects/json2d/validframe/.venv/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~/GitProjects/json2d/validframe/.venv/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Int64Index([1], dtype='int64')] are in the [index]"

# %%
# below are the dataframe manipulations step by step to illustrate the point above:

# %%
df = pd.DataFrame(
    columns = ['a','b','c'],
    data = [
        [1, -42, 1], # row 0
        [1, None, 1], # row 1
        [1, None, 1], # row 2
        [1, 3.14, 1], # row 3
    ]
)

# %%
df.loc[[0,3],['a','c']]
# Out:
#    a  c
# 0  1  1
# 3  1  1

# %%
df.loc[[0,3],['a','c']][df == 1]
df.loc[[0,3],['a','c']].where(df == 1) # same as prev

# %%
df.loc[[0,3],['a','c']][df == 1].count().sum()

# %%
df3 = pd.DataFrame(
      columns = ['a','b','c'],
      data = [
        [1, -42, 1], # row 0
        [1, None, 1], # row 1
        [1, None, 1], # row 2
        [1, 3.14, 1], # row 3
      ]
    )

df3[['a','c']]
df3.loc[[0]]
df3.loc[[0],['a']]
df3.loc[0,'a']
df3.rows
# Out:
# 1

# %%
[i for i, row in df3.iterrows()]
# Out:
# [0, 1, 2, 3]
